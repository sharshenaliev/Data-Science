# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("data.csv")
df=df.sort_values(by=['sotok','summa','keys'], ascending=False)
# df.to_csv("sorted.csv", sep=';')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1007 entries, 388 to 695
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   sotok   1007 non-null   int64
#  1   summa   1007 non-null   int64
#  2   keys    1007 non-null   object
#  3   url     1007 non-null   object
#  4   text    976 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 47.2+ KB

# %%
df.head(5)
# Out:
#      sotok  summa                                               keys  \
# 388   2500  60000   ['/5-bedrooms'. '/besh-kungej'. '/no'. '/owner']
# 304    600  43000  ['/4-bedrooms'. '/no'. '/novo-pokrovka'. '/own...
# 421    420  79000  ['/6-bedrooms'. '/archa-beshik'. '/no'. '/owner']
# 948    100  60000  ['/4-bedrooms'. '/alamedin-rynok'. '/owner'. '...
# 101    100  49000                   ['/5-bedrooms'. '/no'. '/owner']
#
#                                                    url  \
# 388  https://lalafo.kg/bishkek/ads/prodam-dom-180-k...
# 304  https://lalafo.kg/bishkek/ads/prodam-dom-140-k...
# 421  https://lalafo.kg/bishkek/ads/prodam-dom-200-k...
# 948  https://lalafo.kg/bishkek/ads/prodam-dom-90-kv...
# 101  https://lalafo.kg/bishkek/ads/prodam-dom-100-k...
#
#                                                   text
# 388  Продаю 2х уровневые Таунхаусы плошадь:120кв+60...
# 304  Продаю  добротный новый 2020 году завершили. д...
# ...

# %%
df.isna()
# Out:
#      sotok  summa   keys    url   text
# 388  False  False  False  False  False
# 304  False  False  False  False  False
# 421  False  False  False  False  False
# 948  False  False  False  False  False
# 101  False  False  False  False  False
# ..     ...    ...    ...    ...    ...
# 771  False  False  False  False  False
# 468  False  False  False  False  False
# 963  False  False  False  False  False
# 558  False  False  False  False  False
# 695  False  False  False  False  False
#
# [1007 rows x 5 columns]

# %%
df=df.dropna()
len(df)
# Out:
# 973

# %%
df.describe()
# Out:
#              sotok          summa
# count   976.000000     976.000000
# mean     16.190574   42337.707992
# std      83.943318   20621.813080
# min       2.000000   15000.000000
# 25%       6.000000   30000.000000
# 50%       8.000000   40000.000000
# 75%      12.000000   53249.750000
# max    2500.000000  350000.000000

# %%
df = df[df.sotok < 300]

x=df['sotok']
y=df['summa']

plt.scatter(x,y)

# %%
keys = df['keys'].to_numpy()
keys
# Out:
# array(["['/4-bedrooms'. '/alamedin-rynok'. '/owner'. '/yes']",
#        "['/5-bedrooms'. '/no'. '/owner']", "['/6-bedrooms'. '/no']",
#        "['/4-bedrooms'. '/no']",
#        "['/3-bedrooms'. '/no'. '/owner'. '/sokuluk']",
#        "['/4-bedrooms'. '/kara-balta'. '/owner'. '/yes']",
#        "['/3-bedrooms'. '/belovodskoe'. '/owner']",
#        "['/3-bedrooms'. '/kant'. '/owner']",
#        "['/5-bedrooms'. '/lebedinovka'. '/owner'. '/yes']",
#        "['/6-bedrooms'. '/no']", "['/6-bedrooms'. '/no'. '/owner']",
#        "['/3-bedrooms']", "['/3-bedrooms'. '/owner'. '/yes']",
#        "['/7-bedrooms'. '/no'. '/novopavlovka'. '/owner']",
#        "['/3-bedrooms'. '/belovodskoe'. '/no'. '/owner']",
#        "['/4-bedrooms'. '/no']", "['/6-bedrooms'. '/owner'. '/yes']",
#        "['/4-bedrooms'. '/no']",
#        "['/4-bedrooms'. '/kok-zhar'. '/no'. '/owner']",
#        "['/3-bedrooms'. '/no'. '/owner']",
#        "['/4-bedrooms'. '/owner'. '/rabochij-gorodok'. '/yes']",
# ...

# %%
array = np.array(keys)
rooms = []
for i in array:
    try:
        rooms.append(str(i[3]))
    except:
        rooms.append('0')
rooms
# Out:
# ['4',
#  '5',
#  '6',
#  '4',
#  '3',
#  '4',
#  '3',
#  '3',
#  '5',
#  '6',
#  '6',
#  '3',
#  '3',
#  '7',
#  '3',
#  '4',
#  '6',
#  '4',
#  '4',
#  '3',
#  '4',
#  '4',
#  '4',
#  '3',
#  '5',
#  '6',
#  '5',
#  '2',
#  '4',
#  '3',
#  '4',
#  '5',
#  '2',
#  '1',
#  '2',
#  '1',
#  '3',
#  '5',
#  '5',
#  '1',
#  '3',
#  '5',
#  '4',
#  '1',
#  '4',
#  '3',
#  '5',
#  '4',
#  '3',
#  '5',
#  '2',
#  '4',
#  '5',
#  '4',
#  '4',
#  '4',
#  '4',
#  '5',
#  '4',
#  '2',
#  '5',
#  '7',
#  '4',
#  '5',
#  '5',
#  '4',
#  '3',
#  '3',
#  '3',
#  '4',
#  '8',
#  '4',
#  '5',
#  '3',
#  '3',
#  '4',
#  '2',
#  '3',
#  '9',
#  '5',
#  '2',
#  '2',
#  '5',
#  '6',
#  '3',
#  '4',
#  '5',
#  '1',
#  '5',
#  '3',
#  '6',
#  '4',
#  '3',
#  '5',
#  '4',
#  '5',
#  '6',
#  '4',
#  '6',
#  '5',
#  '8',
#  '5',
#  '8',
#  '6',
#  '5',
#  '4',
#  '6',
#  '5',
#  '4',
#  '5',
#  '4',
#  '4',
#  '3',
#  '5',
#  '4',
#  '3',
#  '4',
#  '5',
#  '3',
#  '3',
#  '4',
#  '4',
#  '3',
#  '1',
#  '7',
# ...

# %%
x=rooms
y=df['summa']

plt.scatter(x,y)
